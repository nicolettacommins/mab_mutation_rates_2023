# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from Bio import AlignIO
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import pickle
from scipy.stats import fisher_exact
from statsmodels.stats import multitest

# %% [markdown]
# In this analysis I'm testing the significance of SNP enrichment within clusters including all SNPs no matter how many times they occurred independently in the tree.

# %%
# read in summary of nonsynonymous hits in dominant clusters:
homoplasy_dominant_clust_enrich=pickle.load(open( "../vars/homoplasy_dominant_cluster_enrichment", "rb" ) )

# %%
homoplasy_dominant_clust_enrich=homoplasy_dominant_clust_enrich.sort_values(by='enrichment_p', ascending=True)

# %%
pd.set_option('display.max_colwidth', None)
homoplasy_dominant_clust_enrich.reset_index()
# Out:
#        index Position major minor       Gene  homoplasy_count        Type  \
# 0      53445  4770807     G     A  MAB_4690c                2  intragenic
# 1      47313  4211627     C     T  MAB_4147c                2  intragenic
# 2      13841  1217813     C     T   MAB_1203                3  intragenic
# 3      38491  3381893     C     G  MAB_3334c                4  intragenic
# 4      24054  2119889     G     T  MAB_2120c                6  intragenic
# ...      ...      ...   ...   ...        ...              ...         ...
# 54903  12610  1098819     C     T   MAB_1086                1  intragenic
# 54904  45848  4082630     A     T   MAB_4037                2  intragenic
# 54905  45849  4082799     A     G   MAB_4037                2  intragenic
# 54906  45846  4082354     G     A   MAB_4037                2  intragenic
# 54907  16604  1411962     T     G  MAB_1408c                4  intragenic
#
#                                                                               Product  \
# 0                                                Linear gramicidin synthase subunit D
# 1                                                                hypothetical protein
# 2                                                       Mycothiol S-conjugate amidase
# 3                          Aspartyl/glutamyl-tRNA(Asn/Gln) amidotransferase subunit B
# 4      Putative inactive phenolphthiocerol synthesis polyketide synthase type I Pks15
# ...                                                                               ...
# 54903                                    UTP--glucose-1-phosphate uridylyltransferase
# 54904                                                            hypothetical protein
# 54905                                                            hypothetical protein
# 54906                                                            hypothetical protein
# 54907                    Putative short-chain type dehydrogenase/reductase/MSMEI_5872
#
#        enrichment_p           OR
# 0      1.923486e-71          inf
# 1      3.635388e-69          inf
# 2      4.254548e-67  2914.000000
# 3      1.034483e-65          inf
# 4      1.709089e-64          inf
# ...             ...          ...
# 54903  1.000000e+00          NaN
# 54904  1.000000e+00          NaN
# 54905  1.000000e+00          NaN
# 54906  1.000000e+00          NaN
# 54907  1.000000e+00     1.050505
#
# [54908 rows x 10 columns]

# %%
# first let's merge with the mutation events table to get the change information so I can confirm which changes are synonymous
recombFree_mutation_events=pd.read_csv('../snppar_output/mab_recombinationFree/mab_recombFree_snppar_all_mutation_events.tsv', sep='\t')
# Out:
# /home/nac18/anaconda3/envs/homoplasy/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
recombFree_mutation_events.head()
# Out:
#    Position        Type Ancestor_Node  Derived_Node Ancestor_Call  \
# 0        87  intragenic  NODE_0000002  SAMEA2259646             G
# 1        87  intragenic  NODE_0000013  SAMEA2071363             G
# 2        87  intragenic  NODE_0000039  NODE_0000040             G
# 3        87  intragenic  NODE_0000057  NODE_0000058             G
# 4        87  intragenic  NODE_0000061  SAMN09758982             G
#
#   Derived_Call      Gene Strand Codon Codon_Position  ... Derived_Codon  \
# 0            A  MAB_0001      1    29              3  ...           TCA
# 1            A  MAB_0001      1    29              3  ...           TCA
# 2            A  MAB_0001      1    29              3  ...           TCA
# 3            A  MAB_0001      1    29              3  ...           TCA
# 4            A  MAB_0001      1    29              3  ...           TCA
#
#   Ancestor_A.A. Derived_A.A. Change Up_Gene Up_Gene_Strand Up_Gene_Distance  \
# 0             S            S      S       -              -                -
# 1             S            S      S       -              -                -
# 2             S            S      S       -              -                -
# 3             S            S      S       -              -                -
# 4             S            S      S       -              -                -
#
#   Down_Gene Down_Gene_Strand Down_Gene_Distance
# 0         -                -                  -
# 1         -                -                  -
# 2         -                -                  -
# 3         -                -                  -
# 4         -                -                  -
#
# [5 rows x 21 columns]

# %%
mut_events_sparse=recombFree_mutation_events[['Ancestor_Call', 'Derived_Call', 'Position', 'Change']].rename(columns={"Ancestor_Call": "major", "Derived_Call": "minor"})
mut_events_sparse=mut_events_sparse.drop_duplicates()
mut_events_sparse.head()
# Out:
#    major minor  Position Change
# 0      G     A        87      S
# 6      T     C       162      S
# 10     G     C       192      S
# 12     G     A       201      S
# 18     G     C       219      S

# %%
homoplasy_dominant_clust_enrich=homoplasy_dominant_clust_enrich.astype({'Position': 'int64'})
enriched_vars_change=homoplasy_dominant_clust_enrich.merge(mut_events_sparse, how="left", on=['major', 'minor', 'Position'])
enriched_vars_change.head()
# Out:
#    Position major minor       Gene  homoplasy_count        Type  \
# 0   4770807     G     A  MAB_4690c                2  intragenic
# 1   4211627     C     T  MAB_4147c                2  intragenic
# 2   1217813     C     T   MAB_1203                3  intragenic
# 3   3381893     C     G  MAB_3334c                4  intragenic
# 4   2119889     G     T  MAB_2120c                6  intragenic
#
#                                                                           Product  \
# 0                                            Linear gramicidin synthase subunit D
# 1                                                            hypothetical protein
# 2                                                   Mycothiol S-conjugate amidase
# 3                      Aspartyl/glutamyl-tRNA(Asn/Gln) amidotransferase subunit B
# 4  Putative inactive phenolphthiocerol synthesis polyketide synthase type I Pks15
#
#    enrichment_p      OR Change
# 0  1.923486e-71     inf      S
# 1  3.635388e-69     inf      S
# 2  4.254548e-67  2914.0      S
# 3  1.034483e-65     inf     NS
# 4  1.709089e-64     inf      S

# %%
# divide the data up into synonymous and nonsynonymous variation
ns_vars=enriched_vars_change[enriched_vars_change.Change=='NS']
s_vars=enriched_vars_change[enriched_vars_change.Change=='S']

# %%
# calculate FDR for nonsynonymous SNPs
ns_fdr=multitest.fdrcorrection(ns_vars.enrichment_p)
sum(ns_fdr[0])/len(ns_fdr[0])
# Out:
# 0.5845002079578538

# %%
# calculate FDR for synonymous SNPs
s_fdr=multitest.fdrcorrection(s_vars.enrichment_p)
sum(s_fdr[0])/len(s_fdr[0])
# Out:
# 0.6475437605872388

# %%
# calculate FDR for all SNPs combined
fdr=multitest.fdrcorrection(enriched_vars_change.enrichment_p)
sum(fdr[0])/len(fdr[0])
# Out:
# 0.6274623827869449

# %%
enriched_vars_change.homoplasy_count.value_counts()
# Out:
# 1     24535
# 2      9838
# 3      6341
# 4      4571
# 5      3525
# 6      2472
# 7      1592
# 0       841
# 8       798
# 9       359
# 10      112
# 11       38
# 12        4
# 20        1
# 13        1
# Name: homoplasy_count, dtype: int64
