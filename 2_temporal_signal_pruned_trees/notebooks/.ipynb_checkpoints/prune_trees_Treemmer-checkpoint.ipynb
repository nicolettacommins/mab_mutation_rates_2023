# %% [markdown]
# Reduce M. a. abscessus tree to 95% RTL with Treemmer.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Reduce all sample tree: need to get gubbins output/iqtree input and resulting tree for all passing samples:

# %%
#get list of samples that conserves 95% of diversity 
# !python ~/sw/bin/Treemmer_v0.3.py ../../trees/iqtree/all_passing/mab/mab_all_no_out.contree -RTL 0.95
# Out:
# N of taxa in tree is : 885
#
# Polytomies will be kept
#
# After the pair of leaves with the smallest distance is dentified Treemmer will prune one of the two leaves picked at random
#
# Treemmer will reduce the tree to [0.95] of the original tree length
#
# Treemmer will prune 1 leaves at each iteration
#
# Treemmer will use 1 cpu(s)
#
# iter		1
#
# RTL :	1.0 N_seq:	884
#
# iter		2
#
# RTL :	1.0 N_seq:	883
#
# iter		3
#
# RTL :	0.9999993370136209 N_seq:	882
#
# iter		4
#
# RTL :	0.9999986740272416 N_seq:	881
#
# iter		5
#
# RTL :	0.9999980110408625 N_seq:	880
#
# iter		6
#
# RTL :	0.9999973480544834 N_seq:	879
#
# iter		7
#
# RTL :	0.9999966850681041 N_seq:	878
#
# iter		8
#
# RTL :	0.999996022081725 N_seq:	877
#
# iter		9
#
# RTL :	0.9999953590953459 N_seq:	876
#
# iter		10
#
# RTL :	0.9999946961089666 N_seq:	875
#
# iter		11
#
# RTL :	0.9999940331225875 N_seq:	874
#
# iter		12
#
# RTL :	0.9999933701362084 N_seq:	873
#
# iter		13
#
# RTL :	0.9999927071498291 N_seq:	872
#
# ...
